# %%
print("welcome to Vending Machine!!")
money=float (input("Please put your money in the vending machine: $"))# global variable 

while 1: 
    option=in(input("Please pick up item(1:Coke, 2:Sprite, 3:Mountain Dew, 4: Dr. Pepper, 5: PoweeAde: ) "))
    if money < 0.5: 
        print("You do not have enough money =. Terminate the program due to insufficient money")
        break 
    elif money >= 0.5: 
        if option== 1: 
            print("You picked Coke. The change is $", money - 0.5) # orrr we can set a new local variable of money= money-0.5 and then we plug in the new money value. 
            if money < 0.5: 
                print ("You do not have enough money. Terminate the program due to insufficnet money")
                break 
            else: 
                continue
        elif option == 2: 
            money= money-1.0
            print("You picked Sprite. The change is $", money)
            if money < 1.0:
                print("You do not have enough money for Sprite. Please pick a different item")
                break
            if money >=0.5 and money <1.0: 
                print("You do not have enough money. Terminate the program due to insufficnet money")
                continue 
        elif option == 3: 
            money= money-1.0
            print("You picked Sprite. The change is $", money)
            if money < 1.0:
                print("You do not have enough money for Sprite. Please pick a different item")
                break
            if money >=0.5 and money <1.0: 
                print("You do not have enough money. Terminate the program due to insufficnet money")
                continue 
        elif option == 4: 
            money= money-1.0
            print("You picked Sprite. The change is $", money)
            if money < 1.0:
                print("You do not have enough money for Sprite. Please pick a different item")
                break
            if money >=0.5 and money <1.0: 
                print("You do not have enough money. Terminate the program due to insufficnet money")
                continue 
        elif option == 5: 
            money= money-1.0
            print("You picked Sprite. The change is $", money)
            if money < 1.0:
                print("You do not have enough money for Sprite. Please pick a different item")
                break
            if money >=0.5 and money <1.0: 
                print("You do not have enough money. Terminate the program due to insufficnet money")
                continue
# Out:
#   File "<ipython-input-1-ae6b8ad6578e>", line 5
#     option=in(input("Please pick up item(1:Coke, 2:Sprite, 3:Mountain Dew, 4: Dr. Pepper, 5: PoweeAde: ) "))
#            ^
# SyntaxError: invalid syntax

# %%
"""
"Welcome to the Vending Machine!!\n",
"Please put your money in the vending machine: $4\n",
"Please pick your item (1: Coke, 2: Sprite, 3: Montain Dew, 4: Dr. Pepper, 5: PowerAde: )2\n",
"You picked Sprite. The change is $ 3.0\n",
"Please pick your item (1: Coke, 2: Sprite, 3: Montain Dew, 4: Dr. Pepper, 5: PowerAde: )1\n",
"You picked Coke. The change is $ 2.5\n",
"Please pick your item (1: Coke, 2: Sprite, 3: Montain Dew, 4: Dr. Pepper, 5: PowerAde: )3\n",
"You picked Mountain Dew. The change is $ 1.25\n",
"Please pick your item (1: Coke, 2: Sprite, 3: Montain Dew, 4: Dr. Pepper, 5: PowerAde: )5\n",
"You do not have enough money for PowerAde. Please pick a different item\n",
"Please pick your item (1: Coke, 2: Sprite, 3: Montain Dew, 4: Dr. Pepper, 5: PowerAde: )4\n",
"You picked Dr. Pepper. The change is $ 0.5\n",
"Please pick your item (1: Coke, 2: Sprite, 3: Montain Dew, 4: Dr. Pepper, 5: PowerAde: )2\n",
"You picked Sprite. The change is $ -0.5\n",
"You do not have enough money. Terminate the program due to insufficient money\n"
"""


print("Welcome to the Vending Machine!!")
money = float(input("Please put your money in the vending machine: $")) #global variable
      
      
while 1:
      option = int(input("Please pick your item (1: Coke, 2: Sprite, 3: Montain Dew, 4: Dr. Pepper, 5: PowerAde: )"))
      if money < 0.5:
          print("You do not have enough money. Terminate the program due to insufficient money")
          break
      else:
          if option == 1:
              money = money - 0.5
              print("You picked Coke. The change is $", money)
              if money < 0.5:
                  print("You do not have enough money. Terminate the program due to insufficient money")
                  break
              else:
                  continue
      
      elif option == 2:
        money = money - 1.0
        print("You picked Sprite. The change is $", money)
          if money < 0.5:
              print("You do not have enough money. Terminate the program due to insufficient money")
              break
              if money >=0.5 and money < 1.0:
                  print("You do not have enough money for Sprite. Please pick a different item")
                  continue
      
      elif option == 3:
          if money >= 0.5 and money < 1.25:
              print("You do not have enough money for Mountain Dew. Please pick a different item")
              continue
              if money >= 1.25:
              money = money - 1.25
              print("You picked Mountain Dew. The change is $", money)
                  if money < 0.5:
                      print("You do not have enough money. Terminate the program due to insufficient money")
                      break
      
      elif option == 4:
          if money >=0.5 and money < 0.75:
              print("You do not have enough money for Dr. Pepper. Please pick a different item")
              continue
                 if money >= 0.75:
                     money = money - 0.75
                     print("You picked Dr. Pepper. The change is $", money)
                          if money < 0.5:
                              print("You do not have enough money. Terminate the program due to insufficient money")
                              break
      
      elif option == 5:
          if money >=0.5 and money < 1.50:
              print("You do not have enough money for PowerAde. Please pick a different item")
              continue
              if money >= 1.50:
                  money = money - 1.50
                  print("You picked PowerAde. The change is $", money)
                      if money < 0.5:
                          print("You do not have enough money. Terminate the program due to insufficient money")
                          break
              else:
                  print("You picked a wrong item. Please pick the correct one!!!")
# Out:
#   File "<ipython-input-2-3ba6819642e2>", line 39
#     elif option == 2:
#     ^
# SyntaxError: invalid syntax
